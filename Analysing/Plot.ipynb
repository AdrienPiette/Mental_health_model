# %% [markdown]
# Ploting some stats

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %%
data = pd.read_csv(r'C:\Users\pieta\OneDrive\Bureau\Mental Health Model\Mental_health_model\Data\Impact_of_Remote_Work_on_Mental_Health.csv')

# %%
data.columns
# Out:
# Index(['Employee_ID', 'Age', 'Gender', 'Job_Role', 'Industry',
#        'Years_of_Experience', 'Work_Location', 'Hours_Worked_Per_Week',
#        'Number_of_Virtual_Meetings', 'Work_Life_Balance_Rating',
#        'Stress_Level', 'Mental_Health_Condition',
#        'Access_to_Mental_Health_Resources', 'Productivity_Change',
#        'Social_Isolation_Rating', 'Satisfaction_with_Remote_Work',
#        'Company_Support_for_Remote_Work', 'Physical_Activity', 'Sleep_Quality',
#        'Region'],
#       dtype='object')

# %%
import plotly.express as px

# Age distribution
fig = px.histogram(data, x='Age', nbins=15, title='Age Distribution of Employees', labels={'Age': 'Age', 'count': 'Frequency'}, color_discrete_sequence=['orange', 'teal'])
fig.show()

# %%
# Gender distribution using plotly
fig = px.pie(data, names='Gender', title='Gender Distribution', color_discrete_sequence=['orange', 'teal'])
fig.show()

# %%
# Job role distribution
# Plotting

# Job role distribution using plotly
fig = px.bar(data, x='Job_Role', title='Job Role Distribution', color_discrete_sequence=['darkblue'])
fig.show()

# %%
# Industry distribution
# Plotting

fig = px.bar(data, x='Industry', title='Job Role Distribution', color_discrete_sequence=['darkblue'])
fig.show()

# %%
# Distribution of year of experience
# Plotting

fig = px.histogram(data, x='Years_of_Experience', title='Years of Experience Distribution', labels={'Years_of_Experience': 'Years of Experience', 'count': 'Frequency'}, color_discrete_sequence=['orange', 'teal'])
fig.show()

# %%
# Distribution of Work location
# Plotting

fig = px.pie(data, names='Work_Location', title='Work Location Distribution', color_discrete_sequence=['orange', 'teal'])
fig.show()

# %%
# Distribution of hours worked per week

# Plotting

fig = px.histogram(data, x='Hours_Worked_Per_Week', title='Hours Worked Per Week Distribution', labels={'Hours_Worked_Per_Week': 'Hours Worked Per Week', 'count': 'Frequency'}, color_discrete_sequence=['orange', 'teal'])
fig.show()

# %%
# Distribution of number of virtual meetings per week
# Plotting
fig = px.histogram(data, x='Number_of_Virtual_Meetings', title='Number of Virtual Meetings Per Week Distribution', labels={'Number_of_Virtual_Meetings_Per_Week': 'Number of Virtual Meetings Per Week', 'count': 'Frequency'}, color_discrete_sequence=['orange', 'teal'])
fig.show()

# %%
# distribution of work life balance
# Plotting
fig = px.pie(data, names='Work_Life_Balance_Rating', title='Work Life Balance Distribution', labels={'Work_Life_Balance_Rating': 'Work Life Balance', 'count': 'Frequency'}, color_discrete_sequence=['orange', 'teal'])
fig.show()

# %%
# Distribution of stress level
# Plotting

fig = px.pie(data, names='Stress_Level', title='Stress Level Distribution', labels={'Stress_Level': 'Stress Level', 'count': 'Frequency'}, color_discrete_sequence=['orange', 'teal'])
fig.show()

# %%
# Distribution of mental health status
# Plotting
fig = px.pie(data, names='Mental_Health_Condition', title='Mental Health Status Distribution', labels={'Mental_Health_Status': 'Mental Health Status', 'count': 'Frequency'}, color_discrete_sequence=['orange', 'teal'])
fig.show()

# %%
# Distribution of productivity level
# Plotting

fig = px.pie(data, names='Productivity_Change', title='Productivity Level Distribution', labels={'Productivity_Level': 'Productivity Level', 'count': 'Frequency'}, color_discrete_sequence=['orange', 'teal'])
fig.show()

# %%
# Distribution of social interaction rating
# Plotting
fig = px.pie(data, names='Social_Isolation_Rating', title='Social Interaction Rating Distribution', labels={'Social_Interaction_Rating': 'Social Interaction Rating', 'count': 'Frequency'}, color_discrete_sequence=['orange', 'teal'])
fig.show()

# %%
data.columns
# Out:
# Index(['Employee_ID', 'Age', 'Gender', 'Job_Role', 'Industry',
#        'Years_of_Experience', 'Work_Location', 'Hours_Worked_Per_Week',
#        'Number_of_Virtual_Meetings', 'Work_Life_Balance_Rating',
#        'Stress_Level', 'Mental_Health_Condition',
#        'Access_to_Mental_Health_Resources', 'Productivity_Change',
#        'Social_Isolation_Rating', 'Satisfaction_with_Remote_Work',
#        'Company_Support_for_Remote_Work', 'Physical_Activity', 'Sleep_Quality',
#        'Region'],
#       dtype='object')

# %%
# Distribution of Satisfaction level with remote work   
# Plotting
fig = px.pie(data, names='Satisfaction_with_Remote_Work', title='Satisfaction Level with Remote Work Distribution', labels={'Remote_Work_Satisfaction': 'Remote Work Satisfaction', 'count': 'Frequency'}, color_discrete_sequence=['orange', 'teal'])
fig.show()

# %%
# Distribution of compagny who support remote work
# Plotting

fig = px.pie(data, names='Company_Support_for_Remote_Work', title='Company Support Remote Work Distribution', labels={'Company_Support_Remote_Work': 'Company Support Remote Work', 'count': 'Frequency'}, color_discrete_sequence=['orange', 'teal'])
fig.show()

# %%
# Distribution of Physical activity 
# Plotting

fig = px.pie(data, names='Physical_Activity', title='Physical Activity Distribution', labels={'Physical_Activity': 'Physical Activity', 'count': 'Frequency'}, color_discrete_sequence=['orange', 'teal'])
fig.show()

# %%
# Distribution of sleep quality
# Plotting

fig = px.pie(data, names='Sleep_Quality', title='Sleep Quality Distribution', labels={'Sleep_Quality': 'Sleep Quality', 'count': 'Frequency'}, color_discrete_sequence=['orange', 'teal'])
fig.show()

# %%
# Distribution of Region

# Plotting
fig = px.bar(data, x='Region', title='Region Distribution', color_discrete_sequence=['orange', 'teal'])
fig.show()

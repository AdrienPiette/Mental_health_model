# %% [markdown]
# Ploting some stats

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %%
data = pd.read_csv(r'C:\Users\pieta\OneDrive\Bureau\Mental Health Model\Mental_health_model\Data\Impact_of_Remote_Work_on_Mental_Health.csv')

# %%
# age distribution
# Plotting the age distribution
plt.figure(figsize=(10, 6))
sns.histplot(data['Age'], bins=15, kde=True, palette='viridis')
plt.title('Age Distribution of Employees')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()
# Out:
# C:\Users\pieta\AppData\Local\Temp\ipykernel_23956\2947857012.py:4: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(data['Age'], bins=15, kde=True, palette='viridis')

# %%
# gender distribution

# Plotting
plt.figure(figsize=(10, 6))
plt.pie(data['Gender'].value_counts(), labels=data['Gender'].value_counts().index, autopct='%1.1f%%', startangle=90, colors=['#ff9999', '#66b3ff'])
plt.title('Gender distribution')
plt.show()

# %%
# Job role distribution
# Plotting

plt.figure(figsize=(10, 6))
sns.countplot(data['Job_Role'], palette='viridis')
plt.title('Job Role Distribution')
plt.xlabel('Frequency')
plt.ylabel('Job Role')
plt.xticks(rotation=45)

plt.show()
# Out:
# C:\Users\pieta\AppData\Local\Temp\ipykernel_23956\521192103.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data['Job_Role'], palette='viridis')

# %%
# Industry distribution
# Plotting

plt.figure(figsize=(10, 6))
sns.countplot(data['Industry'], palette='viridis')
plt.title('Industry Distribution')
plt.xlabel('Frequency')
plt.ylabel('Industry')
plt.xticks(rotation=45)

plt.show()
# Out:
# C:\Users\pieta\AppData\Local\Temp\ipykernel_23956\2317522149.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data['Industry'], palette='viridis')

# %%
# Distribution of year of experience
# Plotting

plt.figure(figsize=(10, 6))
sns.histplot(data['Years_of_Experience'], bins=15, kde=True, palette='viridis')
plt.title('Years of Experience Distribution')
plt.xlabel('Years of Experience')
plt.ylabel('Frequency')
plt.show()
# Out:
# C:\Users\pieta\AppData\Local\Temp\ipykernel_23956\256949126.py:5: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(data['Years_of_Experience'], bins=15, kde=True, palette='viridis')

# %%
# Distribution of Work location
# Plotting

plt.figure(figsize=(10, 6))
sns.countplot(data['Work_Location'], palette='viridis')
plt.title('Work Location Distribution')
plt.xlabel('Frequency')
plt.ylabel('Work Location')
plt.xticks(rotation=45)

plt.show()
# Out:
# C:\Users\pieta\AppData\Local\Temp\ipykernel_23956\3643660894.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data['Work_Location'], palette='viridis')

# %%
# Distribution of hours worked per week

# Plotting

plt.figure(figsize=(10, 6))
sns.histplot(data['Hours_Worked_Per_Week'], bins=15, kde=True, color='red')
plt.title('Hours Worked Per Week Distribution')
plt.xlabel('Hours Worked Per Week')
plt.ylabel('Frequency')
plt.show()

# %%
# Distribution of number of virtual meetings per week
# Plotting

plt.figure(figsize=(10, 6))
sns.histplot(data['Number_of_Virtual_Meetings'], bins=15, kde=True, palette='viridis')
plt.title('Number of Virtual Meetings Per Week Distribution')
plt.xlabel('Number of Virtual Meetings Per Week')
plt.ylabel('Frequency')
plt.show()
# Out:
# C:\Users\pieta\AppData\Local\Temp\ipykernel_23956\1921035022.py:5: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(data['Number_of_Virtual_Meetings'], bins=15, kde=True, palette='viridis')

# %%
# distribution of work life balance
# Plotting

# Countplot for Work-Life Balance Rating
plt.figure(figsize=(8, 5))
sns.countplot(data=data, x='Work_Life_Balance_Rating', palette='viridis')   
plt.title('Work-Life Balance Rating')
plt.xlabel('Work-Life Balance Rating')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\pieta\AppData\Local\Temp\ipykernel_23956\3148943782.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=data, x='Work_Life_Balance_Rating', palette='viridis')

# %%
# Distribution of stress level
# Plotting

plt.figure(figsize=(8, 5))
sns.countplot(data=data, x='Stress_Level', palette='viridis')
plt.title('Stress Level')
plt.xlabel('Stress Level')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\pieta\AppData\Local\Temp\ipykernel_23956\1800369712.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=data, x='Stress_Level', palette='viridis')

# %%
# Distribution of mental health status
# Plotting

plt.figure(figsize=(8, 5))
sns.countplot(data=data, x='Mental_Health_Condition', palette='viridis')
plt.title('Mental Health Condition')
plt.xlabel('Mental Health Condition')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\pieta\AppData\Local\Temp\ipykernel_23956\492399717.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=data, x='Mental_Health_Condition', palette='viridis')

# %%
# Distribution of productivity level
# Plotting

plt.figure(figsize=(8, 5))
sns.countplot(data=data, x='Productivity_Change', palette='viridis')
plt.title('Productivity Change')
plt.xlabel('Productivity Change')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\pieta\AppData\Local\Temp\ipykernel_23956\918645402.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=data, x='Productivity_Change', palette='viridis')

# %%
# Distribution of social interaction rating
# Plotting

plt.figure(figsize=(8, 5))
sns.countplot(data=data, x='Social_Isolation_Rating', palette='viridis')
plt.title('Social Isolation Rating')
plt.xlabel('Social Isolation Rating')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\pieta\AppData\Local\Temp\ipykernel_23956\1242422288.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=data, x='Social_Isolation_Rating', palette='viridis')

# %%
# Distribution of Satisfaction level with remote work   
# Plotting

plt.figure(figsize=(8, 5))
sns.countplot(data=data, x='Satisfaction_with_Remote_Work', palette='viridis')
plt.title('Satisfaction with Remote Work')
plt.xlabel('Satisfaction with Remote Work')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\pieta\AppData\Local\Temp\ipykernel_23956\3451957667.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=data, x='Satisfaction_with_Remote_Work', palette='viridis')

# %%
# Distribution of compagny who support remote work
# Plotting

plt.figure(figsize=(8, 5))
sns.countplot(data=data, x='Company_Support_for_Remote_Work', palette='viridis')    
plt.title('Company Support Remote Work')
plt.xlabel('Company Support Remote Work')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\pieta\AppData\Local\Temp\ipykernel_23956\107658883.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=data, x='Company_Support_for_Remote_Work', palette='viridis')

# %%
# Distribution of Physical activity 
# Plotting

plt.figure(figsize=(8, 5))
sns.countplot(data=data, x='Physical_Activity', palette='viridis')  
plt.title('Physical Activity')
plt.xlabel('Physical Activity')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\pieta\AppData\Local\Temp\ipykernel_23956\1917728149.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=data, x='Physical_Activity', palette='viridis')

# %%
# Distribution of sleep quality
# Plotting

plt.figure(figsize=(8, 5))
sns.countplot(data=data, x='Sleep_Quality', palette='viridis')
plt.title('Sleep Quality')
plt.xlabel('Sleep Quality')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\pieta\AppData\Local\Temp\ipykernel_23956\2374798356.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=data, x='Sleep_Quality', palette='viridis')

# %%
# Distribution of Region

# Plotting

plt.figure(figsize=(10, 6))
sns.countplot(data['Region'], palette='viridis')
plt.title('Region Distribution')
plt.xlabel('Frequency')
plt.ylabel('Region')
plt.xticks(rotation=45)

plt.show()
# Out:
# C:\Users\pieta\AppData\Local\Temp\ipykernel_23956\1500158056.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data['Region'], palette='viridis')
